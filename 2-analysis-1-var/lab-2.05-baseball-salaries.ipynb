# %% [markdown]
# # Lab 2.05 - Univariate Analysis

# %%
# Importing the necessary packages
import numpy as np                                  # "Scientific computing"
import scipy.stats as stats                         # Statistical tests

import pandas as pd                                 # Data Frame
from pandas.api.types import CategoricalDtype

import matplotlib.pyplot as plt                     # Basic visualisation
from statsmodels.graphics.mosaicplot import mosaic  # Mosaic diagram
import seaborn as sns                               # Advanced data visualisation

# %% [markdown]
# ## Exercise 5 - Baseball Salaries
#
# The file Baseball Salaries contains data on 868 Major League Baseball (MLB) players in the 2011 season. There are four variables: the player's name, team, position, and salary. How can these 868 salaries be summarized?
#
# - Calculate the mean, the median and the mode (i.e. measures of central tendency)
# - Calculate the minimum, maximum, quartiles
# - Calculate the range, interquartile range, variance, standard deviation (i.e. measures of variability)
# - Calculate the skewness and Kurtosis (i.e. measures of shape)
# - Draw a histogram. Use 11 bins with equal width. Does it indicate skewness?
# - Draw a boxplot. Does it indicate skewness?

# %%
bb = pd.read_csv('../data/Baseball Salaries 2011.csv', delimiter=";")
# Show the first few records of the Data Frame
bb.head()
# Out:
#             Player                 Team Position    Salary
# 0     A.J. Burnett     New York Yankees  Pitcher  16500000
# 1       A.J. Ellis  Los Angeles Dodgers  Catcher    421000
# 2  A.J. Pierzynski    Chicago White Sox  Catcher   2000000
# 3       Aaron Cook     Colorado Rockies  Pitcher   9875000
# 4       Aaron Crow   Kansas City Royals  Pitcher   1400000

# %%
bb_median = np.median(bb.Salary)
bb_mean = np.mean(bb.Salary).round(3)
bb_mode = stats.mode(bb.Salary, keepdims=True)
bb_mode2 = bb.Salary.mode()
bb_std = bb.Salary.std()
# Variantie (Variance)
var = bb.Salary.var()


skew = stats.skew(bb.Salary)


kurt = stats.kurtosis(bb.Salary)

min_val = bb.Salary.min()
max_val = bb.Salary.max()


range_val = max_val - min_val

percentiles = bb.Salary.quantile([0, 0.25, 0.5, 0.75, 1.0])

iqr = percentiles[0.75] - percentiles[0.25]
print("Mode2: ", bb_mode2)
print("Mode:", bb_mode.mode)
print("Median:", bb_median)
print("Mean:", bb_mean)
print("std: ", bb_std)
print(f"Variance: {var}")
print(f"Skewness: {skew}")
print(f"Kurtosis: {kurt}")
print(f"Minimum: {min_val}")
print(f"Maximum: {max_val}")
print(f"Range: {range_val}")
print(f"Inter Quartile Range: {iqr}")
# Out:
# Mode2:  0    414000
# Name: Salary, dtype: int64
# Mode: [414000]
# Median: 1175000.0
# Mean: 3305054.675
# std:  4534742.272591988
# Variance: 20563887478832.742
# Skewness: 2.252809124933155
# Kurtosis: 5.682260665213221
# Minimum: 414000
# Maximum: 32000000
# Range: 31586000
# Inter Quartile Range: 3875925.0

# %%
bb_max = np.max(bb.Salary)
bb_min = np.min(bb.Salary)
print("Max: ", bb_max)
print("Min: ", bb_min)
# Out:
# Max:  32000000
# Min:  414000

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
g = sns.histplot(data=bb.Salary, bins=11)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
b = sns.boxplot(x=bb.Salary)

# %% [markdown]
# ## Answers
#
# |      Statistic       |              Value |
# | :------------------: | -----------------: |
# |         Mean         |        3305054.675 |
# |        Median        |          1175000.0 |
# |         Mode         |        0    414000 |
# |  Standard deviation  |        4534742.273 |
# |       Variance       | 20563887478832.742 |
# |       Skewness       |              2.257 |
# |       Kurtosis       |              5.723 |
# |       Minimum        |             414000 |
# |        Median        |          1175000.0 |
# |       Maximum        |           32000000 |
# | Inter Quartile Range |          3875925.0 |
# |        Range         |           31586000 |
#
# | Percentiles  |       Value |
# | :----------: | ----------: |
# |     0.00     |    414000.0 |
# |     0.25     |    430325.0 |
# |     0.50     |   1175000.0 |
# |     0.75     |   4306250.0 |
# |     1.00     |  32000000.0 |
